# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Getting started with neural networks: Classification and regression

# %% [markdown]
# ## Classifying movie reviews: A binary classification example

# %% [markdown]
# ### The IMDB dataset

# %% [markdown]
# **Loading the IMDB dataset**

# %%
from tensorflow.keras.datasets import imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# 1

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %% [markdown]
# **Decoding reviews back to text**

# %%
word_index = imdb.get_word_index()
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 0s 0us/step

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# **Encoding the integer sequences via multi-hot encoding**

# %%
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, j] = 1.
    return results
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %% [markdown]
# ### Building your model

# %% [markdown]
# **Model definition**

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="relu"), # hidden layer
    layers.Dense(1, activation="sigmoid")
])

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"), # hidden layer
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
model = keras.Sequential([
    layers.Dense(100, activation="relu"), # hidden layer
    layers.Dense(1, activation="sigmoid")
])

# %%
import tensorflow as tf

model = keras.Sequential([
    layers.Dense(16, activation=tf.keras.activations.tanh),
    layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# **Compiling the model**

# %%
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# %%
model.compile(optimizer="rmsprop",
              loss="mean_squared_error",
              metrics=["accuracy"])

# %% [markdown]
# ### Validating your approach

# %% [markdown]
# **Setting aside a validation set**

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %% [markdown]
# **Training your model**

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 65ms/step - loss: 0.1794 - accuracy: 0.7823 - val_loss: 0.1332 - val_accuracy: 0.8603
# Epoch 2/20
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1125 - accuracy: 0.8846 - val_loss: 0.1078 - val_accuracy: 0.8767
# Epoch 3/20
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0882 - accuracy: 0.9075 - val_loss: 0.0969 - val_accuracy: 0.8825
# Epoch 4/20
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0744 - accuracy: 0.9206 - val_loss: 0.0907 - val_accuracy: 0.8855
# Epoch 5/20
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0656 - accuracy: 0.9281 - val_loss: 0.0890 - val_accuracy: 0.8861
# Epoch 6/20
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0589 - accuracy: 0.9394 - val_loss: 0.0862 - val_accuracy: 0.8858
# Epoch 7/20
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0541 - accuracy: 0.9419 - val_loss: 0.0866 - val_accuracy: 0.8828
# Epoch 8/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0497 - accuracy: 0.9498 - val_loss: 0.0842 - val_accuracy: 0.8840
# Epoch 9/20
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0462 - accuracy: 0.9545 - val_loss: 0.0840 - val_accuracy: 0.8835
# Epoch 10/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0428 - accuracy: 0.9577 - val_loss: 0.0873 - val_accuracy: 0.8798
# Epoch 11/20
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0400 - accuracy: 0.9607 - val_loss: 0.0919 - val_accuracy: 0.8735
# Epoch 12/20
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0375 - accuracy: 0.9655 - val_loss: 0.0859 - val_accuracy: 0.8826
# Epoch 13/20
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0352 - accuracy: 0.9684 - val_loss: 0.0868 - val_accuracy: 0.8791
# Epoch 14/20
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0333 - accuracy: 0.9707 - val_loss: 0.0872 - val_accuracy: 0.8815
# Epoch 15/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0317 - accuracy: 0.9725 - val_loss: 0.0866 - val_accuracy: 0.8790
# Epoch 16/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0296 - accuracy: 0.9759 - val_loss: 0.0863 - val_accuracy: 0.8807
# Epoch 17/20
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0283 - accuracy: 0.9769 - val_loss: 0.0870 - val_accuracy: 0.8807
# Epoch 18/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0265 - accuracy: 0.9787 - val_loss: 0.0876 - val_accuracy: 0.8794
# Epoch 19/20
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0256 - accuracy: 0.9799 - val_loss: 0.0888 - val_accuracy: 0.8786
# Epoch 20/20
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0241 - accuracy: 0.9817 - val_loss: 0.0891 - val_accuracy: 0.8785

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# **Plotting the training and validation loss**

# %%
# hiden layer 1개
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# 3개
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# units = 100
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# using the tanh activation instead of relu
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# using the mseloss function instead of binary_crossentropy
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# **Plotting the training and validation accuracy**

# %%
# 1개

plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# 3개

plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# units = 100
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# using the tanh activation instead of relu
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# using the mseloss function instead of binary_crossentropy
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# **Retraining a model from scratch**

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 3s 32ms/step - loss: 0.4973 - accuracy: 0.8110
# Epoch 2/4
# 49/49 [==============================] - 2s 32ms/step - loss: 0.2955 - accuracy: 0.8982
# Epoch 3/4
# 49/49 [==============================] - 2s 32ms/step - loss: 0.2267 - accuracy: 0.9188
# Epoch 4/4
# 49/49 [==============================] - 2s 33ms/step - loss: 0.1910 - accuracy: 0.9319
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2799 - accuracy: 0.8884

# %%
results
# Out:
# [0.27994194626808167, 0.8883600234985352]

# %% [markdown]
# ### Using a trained model to generate predictions on new data

# %%
model.predict(x_test)
# Out:
# 782/782 [==============================] - 3s 3ms/step
# array([[0.1969647 ],
#        [0.99971664],
#        [0.8003495 ],
#        ...,
#        [0.09032901],
#        [0.10700704],
#        [0.5780724 ]], dtype=float32)

# %% [markdown]
# ### Further experiments

# %% [markdown]
# ### Wrapping up

# %% [markdown]
# ## Classifying newswires: A multiclass classification example

# %% [markdown]
# ### The Reuters dataset

# %% [markdown]
# **Loading the Reuters dataset**

# %%
from tensorflow.keras.datasets import reuters
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
    num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %% [markdown]
# **Decoding newswires back to text**

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = " ".join([reverse_word_index.get(i - 3, "?") for i in
    train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 550378/550378 [==============================] - 0s 0us/step

# %%
train_labels[10]
# Out:
# 3

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# **Encoding the input data**

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %% [markdown]
# **Encoding the labels**

# %%
def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results
y_train = to_one_hot(train_labels)
y_test = to_one_hot(test_labels)

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# ### Building your model

# %% [markdown]
# **Model definition**

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(46, activation="softmax")
])

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(46, activation="softmax")
])

# %% [markdown]
# **Compiling the model**

# %%
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Validating your approach

# %% [markdown]
# **Setting aside a validation set**

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %% [markdown]
# **Training the model**

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 2s 73ms/step - loss: 2.7309 - accuracy: 0.4847 - val_loss: 1.8323 - val_accuracy: 0.5790
# Epoch 2/20
# 16/16 [==============================] - 1s 51ms/step - loss: 1.5960 - accuracy: 0.6450 - val_loss: 1.4523 - val_accuracy: 0.6860
# Epoch 3/20
# 16/16 [==============================] - 1s 79ms/step - loss: 1.2681 - accuracy: 0.7146 - val_loss: 1.2594 - val_accuracy: 0.7230
# Epoch 4/20
# 16/16 [==============================] - 2s 98ms/step - loss: 1.0669 - accuracy: 0.7556 - val_loss: 1.1624 - val_accuracy: 0.7330
# Epoch 5/20
# 16/16 [==============================] - 1s 67ms/step - loss: 0.8978 - accuracy: 0.7965 - val_loss: 1.1006 - val_accuracy: 0.7550
# Epoch 6/20
# 16/16 [==============================] - 1s 59ms/step - loss: 0.7607 - accuracy: 0.8304 - val_loss: 1.1642 - val_accuracy: 0.7340
# Epoch 7/20
# 16/16 [==============================] - 1s 53ms/step - loss: 0.6305 - accuracy: 0.8588 - val_loss: 1.0244 - val_accuracy: 0.7760
# Epoch 8/20
# 16/16 [==============================] - 1s 50ms/step - loss: 0.5400 - accuracy: 0.8816 - val_loss: 1.0535 - val_accuracy: 0.7640
# Epoch 9/20
# 16/16 [==============================] - 1s 48ms/step - loss: 0.4521 - accuracy: 0.9007 - val_loss: 0.9870 - val_accuracy: 0.7960
# Epoch 10/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.3879 - accuracy: 0.9156 - val_loss: 0.9900 - val_accuracy: 0.8020
# Epoch 11/20
# 16/16 [==============================] - 1s 54ms/step - loss: 0.3273 - accuracy: 0.9286 - val_loss: 1.0120 - val_accuracy: 0.7970
# Epoch 12/20
# 16/16 [==============================] - 1s 56ms/step - loss: 0.2944 - accuracy: 0.9374 - val_loss: 0.9769 - val_accuracy: 0.8160
# Epoch 13/20
# 16/16 [==============================] - 1s 59ms/step - loss: 0.2461 - accuracy: 0.9439 - val_loss: 1.0767 - val_accuracy: 0.8010
# Epoch 14/20
# 16/16 [==============================] - 1s 60ms/step - loss: 0.2279 - accuracy: 0.9474 - val_loss: 1.0516 - val_accuracy: 0.8030
# Epoch 15/20
# 16/16 [==============================] - 1s 60ms/step - loss: 0.2065 - accuracy: 0.9504 - val_loss: 1.0367 - val_accuracy: 0.8120
# Epoch 16/20
# 16/16 [==============================] - 1s 72ms/step - loss: 0.1910 - accuracy: 0.9506 - val_loss: 1.0737 - val_accuracy: 0.7970
# Epoch 17/20
# 16/16 [==============================] - 2s 96ms/step - loss: 0.1756 - accuracy: 0.9529 - val_loss: 1.0781 - val_accuracy: 0.8000
# Epoch 18/20
# 16/16 [==============================] - 1s 79ms/step - loss: 0.1648 - accuracy: 0.9546 - val_loss: 1.1431 - val_accuracy: 0.7900
# Epoch 19/20
# 16/16 [==============================] - 1s 58ms/step - loss: 0.1516 - accuracy: 0.9555 - val_loss: 1.1977 - val_accuracy: 0.7920
# Epoch 20/20
# 16/16 [==============================] - 1s 57ms/step - loss: 0.1485 - accuracy: 0.9562 - val_loss: 1.1187 - val_accuracy: 0.7940

# %% [markdown]
# **Plotting the training and validation loss**

# %%
# 1 hidden layer
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# 3 hidden layers
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# **Plotting the training and validation accuracy**

# %%
# 1 hidden layer
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# 3 hidden layers
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# **Retraining a model from scratch**

# %%
model = keras.Sequential([
  layers.Dense(64, activation="relu"),
  layers.Dense(64, activation="relu"),
  layers.Dense(46, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(x_train,
          y_train,
          epochs=9,
          batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 [==============================] - 2s 55ms/step - loss: 2.6282 - accuracy: 0.4912
# Epoch 2/9
# 18/18 [==============================] - 1s 65ms/step - loss: 1.5260 - accuracy: 0.6769
# Epoch 3/9
# 18/18 [==============================] - 1s 83ms/step - loss: 1.1687 - accuracy: 0.7454
# Epoch 4/9
# 18/18 [==============================] - 1s 58ms/step - loss: 0.9493 - accuracy: 0.7924
# Epoch 5/9
# 18/18 [==============================] - 1s 47ms/step - loss: 0.7835 - accuracy: 0.8337
# Epoch 6/9
# 18/18 [==============================] - 1s 53ms/step - loss: 0.6517 - accuracy: 0.8631
# Epoch 7/9
# 18/18 [==============================] - 1s 53ms/step - loss: 0.5452 - accuracy: 0.8848
# Epoch 8/9
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4621 - accuracy: 0.9041
# Epoch 9/9
# 18/18 [==============================] - 1s 56ms/step - loss: 0.3952 - accuracy: 0.9143
# 71/71 [==============================] - 1s 6ms/step - loss: 0.9158 - accuracy: 0.7881

# %%
results
# Out:
# [0.915800929069519, 0.7880676984786987]

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels) == np.array(test_labels_copy)
hits_array.mean()
# Out:
# 0.18432769367764915

# %% [markdown]
# ### Generating predictions on new data

# %%
predictions = model.predict(x_test)
# Out:
# 71/71 [==============================] - 0s 4ms/step

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# 1.0000001

# %%
np.argmax(predictions[0])
# Out:
# 3

# %% [markdown]
# ### A different way to handle the labels and the loss

# %%
y_train = np.array(train_labels)
y_test = np.array(test_labels)

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### The importance of having sufficiently large intermediate layers

# %% [markdown]
# **A model with an information bottleneck**

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(4, activation="relu"),
    layers.Dense(46, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 63/63 [==============================] - 2s 26ms/step - loss: 2.9309 - accuracy: 0.3147 - val_loss: 2.2744 - val_accuracy: 0.4440
# Epoch 2/20
# 63/63 [==============================] - 1s 20ms/step - loss: 1.8942 - accuracy: 0.4739 - val_loss: 1.6570 - val_accuracy: 0.5890
# Epoch 3/20
# 63/63 [==============================] - 1s 21ms/step - loss: 1.4058 - accuracy: 0.6629 - val_loss: 1.3989 - val_accuracy: 0.6700
# Epoch 4/20
# 63/63 [==============================] - 1s 18ms/step - loss: 1.1716 - accuracy: 0.7052 - val_loss: 1.3080 - val_accuracy: 0.6930
# Epoch 5/20
# 63/63 [==============================] - 1s 19ms/step - loss: 1.0404 - accuracy: 0.7284 - val_loss: 1.3156 - val_accuracy: 0.6850
# Epoch 6/20
# 63/63 [==============================] - 1s 20ms/step - loss: 0.9452 - accuracy: 0.7592 - val_loss: 1.2672 - val_accuracy: 0.7100
# Epoch 7/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.8646 - accuracy: 0.7775 - val_loss: 1.2617 - val_accuracy: 0.7090
# Epoch 8/20
# 63/63 [==============================] - 2s 32ms/step - loss: 0.7999 - accuracy: 0.7883 - val_loss: 1.2624 - val_accuracy: 0.7220
# Epoch 9/20
# 63/63 [==============================] - 1s 22ms/step - loss: 0.7436 - accuracy: 0.7969 - val_loss: 1.2948 - val_accuracy: 0.7150
# Epoch 10/20
# 63/63 [==============================] - 1s 20ms/step - loss: 0.6968 - accuracy: 0.8109 - val_loss: 1.3107 - val_accuracy: 0.7190
# Epoch 11/20
# 63/63 [==============================] - 1s 20ms/step - loss: 0.6553 - accuracy: 0.8222 - val_loss: 1.3183 - val_accuracy: 0.7280
# Epoch 12/20
# 63/63 [==============================] - 1s 21ms/step - loss: 0.6198 - accuracy: 0.8339 - val_loss: 1.3836 - val_accuracy: 0.7210
# Epoch 13/20
# 63/63 [==============================] - 1s 20ms/step - loss: 0.5864 - accuracy: 0.8404 - val_loss: 1.4039 - val_accuracy: 0.7250
# Epoch 14/20
# 63/63 [==============================] - 1s 22ms/step - loss: 0.5558 - accuracy: 0.8483 - val_loss: 1.4864 - val_accuracy: 0.7110
# Epoch 15/20
# 63/63 [==============================] - 1s 20ms/step - loss: 0.5303 - accuracy: 0.8568 - val_loss: 1.4870 - val_accuracy: 0.7310
# Epoch 16/20
# 63/63 [==============================] - 1s 17ms/step - loss: 0.5092 - accuracy: 0.8627 - val_loss: 1.5092 - val_accuracy: 0.7250
# Epoch 17/20
# 63/63 [==============================] - 2s 28ms/step - loss: 0.4870 - accuracy: 0.8685 - val_loss: 1.5555 - val_accuracy: 0.7300
# Epoch 18/20
# 63/63 [==============================] - 2s 28ms/step - loss: 0.4655 - accuracy: 0.8771 - val_loss: 1.5759 - val_accuracy: 0.7300
# Epoch 19/20
# 63/63 [==============================] - 1s 17ms/step - loss: 0.4496 - accuracy: 0.8846 - val_loss: 1.6323 - val_accuracy: 0.7230
# Epoch 20/20
# 63/63 [==============================] - 1s 20ms/step - loss: 0.4295 - accuracy: 0.8894 - val_loss: 1.7073 - val_accuracy: 0.7210

# %% [markdown]
# ### Further experiments

# %% [markdown]
# ### Wrapping up

# %% [markdown]
# ## Predicting house prices: A regression example

# %% [markdown]
# ### The Boston Housing Price dataset

# %% [markdown]
# **Loading the Boston housing dataset**

# %%
from tensorflow.keras.datasets import boston_housing
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
train_data.shape
# Out:
# (404, 13)

# %%
test_data.shape
# Out:
# (102, 13)

# %%
train_targets
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4, 12.1,
#        17.9, 23.1, 19.9, 15.7,  8.8, 50. , 22.5, 24.1, 27.5, 10.9, 30.8,
#        32.9, 24. , 18.5, 13.3, 22.9, 34.7, 16.6, 17.5, 22.3, 16.1, 14.9,
#        23.1, 34.9, 25. , 13.9, 13.1, 20.4, 20. , 15.2, 24.7, 22.2, 16.7,
#        12.7, 15.6, 18.4, 21. , 30.1, 15.1, 18.7,  9.6, 31.5, 24.8, 19.1,
#        22. , 14.5, 11. , 32. , 29.4, 20.3, 24.4, 14.6, 19.5, 14.1, 14.3,
#        15.6, 10.5,  6.3, 19.3, 19.3, 13.4, 36.4, 17.8, 13.5, 16.5,  8.3,
#        14.3, 16. , 13.4, 28.6, 43.5, 20.2, 22. , 23. , 20.7, 12.5, 48.5,
#        14.6, 13.4, 23.7, 50. , 21.7, 39.8, 38.7, 22.2, 34.9, 22.5, 31.1,
#        28.7, 46. , 41.7, 21. , 26.6, 15. , 24.4, 13.3, 21.2, 11.7, 21.7,
#        19.4, 50. , 22.8, 19.7, 24.7, 36.2, 14.2, 18.9, 18.3, 20.6, 24.6,
#        18.2,  8.7, 44. , 10.4, 13.2, 21.2, 37. , 30.7, 22.9, 20. , 19.3,
#        31.7, 32. , 23.1, 18.8, 10.9, 50. , 19.6,  5. , 14.4, 19.8, 13.8,
#        19.6, 23.9, 24.5, 25. , 19.9, 17.2, 24.6, 13.5, 26.6, 21.4, 11.9,
#        22.6, 19.6,  8.5, 23.7, 23.1, 22.4, 20.5, 23.6, 18.4, 35.2, 23.1,
#        27.9, 20.6, 23.7, 28. , 13.6, 27.1, 23.6, 20.6, 18.2, 21.7, 17.1,
#         8.4, 25.3, 13.8, 22.2, 18.4, 20.7, 31.6, 30.5, 20.3,  8.8, 19.2,
#        19.4, 23.1, 23. , 14.8, 48.8, 22.6, 33.4, 21.1, 13.6, 32.2, 13.1,
#        23.4, 18.9, 23.9, 11.8, 23.3, 22.8, 19.6, 16.7, 13.4, 22.2, 20.4,
#        21.8, 26.4, 14.9, 24.1, 23.8, 12.3, 29.1, 21. , 19.5, 23.3, 23.8,
#        17.8, 11.5, 21.7, 19.9, 25. , 33.4, 28.5, 21.4, 24.3, 27.5, 33.1,
#        16.2, 23.3, 48.3, 22.9, 22.8, 13.1, 12.7, 22.6, 15. , 15.3, 10.5,
#        24. , 18.5, 21.7, 19.5, 33.2, 23.2,  5. , 19.1, 12.7, 22.3, 10.2,
#        13.9, 16.3, 17. , 20.1, 29.9, 17.2, 37.3, 45.4, 17.8, 23.2, 29. ,
#        22. , 18. , 17.4, 34.6, 20.1, 25. , 15.6, 24.8, 28.2, 21.2, 21.4,
#        23.8, 31. , 26.2, 17.4, 37.9, 17.5, 20. ,  8.3, 23.9,  8.4, 13.8,
#         7.2, 11.7, 17.1, 21.6, 50. , 16.1, 20.4, 20.6, 21.4, 20.6, 36.5,
#         8.5, 24.8, 10.8, 21.9, 17.3, 18.9, 36.2, 14.9, 18.2, 33.3, 21.8,
#        19.7, 31.6, 24.8, 19.4, 22.8,  7.5, 44.8, 16.8, 18.7, 50. , 50. ,
#        19.5, 20.1, 50. , 17.2, 20.8, 19.3, 41.3, 20.4, 20.5, 13.8, 16.5,
#        23.9, 20.6, 31.5, 23.3, 16.8, 14. , 33.8, 36.1, 12.8, 18.3, 18.7,
#        19.1, 29. , 30.1, 50. , 50. , 22. , 11.9, 37.6, 50. , 22.7, 20.8,
#        23.5, 27.9, 50. , 19.3, 23.9, 22.6, 15.2, 21.7, 19.2, 43.8, 20.3,
#        33.2, 19.9, 22.5, 32.7, 22. , 17.1, 19. , 15. , 16.1, 25.1, 23.7,
#        28.7, 37.2, 22.6, 16.4, 25. , 29.8, 22.1, 17.4, 18.1, 30.3, 17.5,
#        24.7, 12.6, 26.5, 28.7, 13.3, 10.4, 24.4, 23. , 20. , 17.8,  7. ,
#        11.8, 24.4, 13.8, 19.4, 25.2, 19.4, 19.4, 29.1])

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# **Normalizing the data**

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
test_data -= mean
test_data /= std

# %% [markdown]
# ### Building your model

# %% [markdown]
# **Model definition**

# %%
def build_model():
    model = keras.Sequential([
        layers.Dense(64, activation="relu"),
        layers.Dense(1)
    ])
    model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
    return model

# %%
def build_model():
    model = keras.Sequential([
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(1)
    ])
    model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
    return model

# %%
def build_model():
    model = keras.Sequential([
        layers.Dense(100, activation="relu"),
        layers.Dense(100, activation="relu"),
        layers.Dense(100, activation="relu"),
        layers.Dense(1)
    ])
    model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
    return model

# %% [markdown]
# ### Validating your approach using K-fold validation

# %% [markdown]
# **K-fold validation**

# %%
k = 4
num_val_samples = len(train_data) // k
num_epochs = 100
all_scores = []
for i in range(k):
    print(f"Processing fold #{i}")
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)
    model = build_model()
    model.fit(partial_train_data, partial_train_targets,
              epochs=num_epochs, batch_size=16, verbose=0)
    val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
    all_scores.append(val_mae)
# Out:
# Processing fold #0
# Processing fold #1
# Processing fold #2
# Processing fold #3

# %%
all_scores
# Out:
# [2.0713605880737305, 2.513170003890991, 2.468890428543091, 2.469409942626953]

# %%
np.mean(all_scores)
# Out:
# 2.3807077407836914

# %% [markdown]
# **Saving the validation logs at each fold**

# %%
num_epochs = 500
all_mae_histories = []
for i in range(k):
    print(f"Processing fold #{i}")
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)
    model = build_model()
    history = model.fit(partial_train_data, partial_train_targets,
                        validation_data=(val_data, val_targets),
                        epochs=num_epochs, batch_size=16, verbose=0)
    mae_history = history.history["val_mae"]
    all_mae_histories.append(mae_history)
# Out:
# Processing fold #0
# Processing fold #1
# Processing fold #2
# Processing fold #3

# %% [markdown]
# **Building the history of successive mean K-fold validation scores**

# %%
average_mae_history = [
    np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)]

# %% [markdown]
# **Plotting validation scores**

# %%
plt.plot(range(1, len(average_mae_history) + 1), average_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %% [markdown]
# **Plotting validation scores, excluding the first 10 data points**

# %%
truncated_mae_history = average_mae_history[10:]
plt.plot(range(1, len(truncated_mae_history) + 1), truncated_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %% [markdown]
# **Training the final model**

# %%
model = build_model()
model.fit(train_data, train_targets,
          epochs=130, batch_size=16, verbose=0)
test_mse_score, test_mae_score = model.evaluate(test_data, test_targets)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 19.5493 - mae: 2.7687

# %%
test_mae_score
# Out:
# 2.76870059967041

# %% [markdown]
# ### Generating predictions on new data

# %%
predictions = model.predict(test_data)
predictions[0]
# Out:
# 4/4 [==============================] - 0s 2ms/step
# array([8.52714], dtype=float32)

# %% [markdown]
# ### Wrapping up

# %% [markdown]
# ## Summary
